# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs
import time

# %%
# URL of the website to scrape
url = "http://books.toscrape.com/"

# Send a request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = bs(response.text, 'html.parser')

    # Initialize a list to store book data
    books = []

    # Loop through each book entry in the HTML
    for book in soup.find_all('article', class_='product_pod'):
        # Extracting book title
        title = book.h3.a['title']
        
        # Extracting book rating
        rating = book.p['class'][1]
        
        # Extracting book price
        price = book.find('p', class_='price_color').text
        
        # Extracting book link
        link = url + book.h3.a['href']

        # Add the book data to the list
        books.append({'title': title, 'rating': rating, 'price': price, 'link': link})

        time.sleep(1)

    # Print the list of books
    for book in books:
        print(book)
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")
# Out:
# {'title': 'A Light in the Attic', 'rating': 'Three', 'price': 'Â£51.77', 'link': 'http://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'}
# {'title': 'Tipping the Velvet', 'rating': 'One', 'price': 'Â£53.74', 'link': 'http://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html'}
# {'title': 'Soumission', 'rating': 'One', 'price': 'Â£50.10', 'link': 'http://books.toscrape.com/catalogue/soumission_998/index.html'}
# {'title': 'Sharp Objects', 'rating': 'Four', 'price': 'Â£47.82', 'link': 'http://books.toscrape.com/catalogue/sharp-objects_997/index.html'}
# {'title': 'Sapiens: A Brief History of Humankind', 'rating': 'Five', 'price': 'Â£54.23', 'link': 'http://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html'}
# {'title': 'The Requiem Red', 'rating': 'One', 'price': 'Â£22.65', 'link': 'http://books.toscrape.com/catalogue/the-requiem-red_995/index.html'}
# {'title': 'The Dirty Little Secrets of Getting Your Dream Job', 'rating': 'Four', 'price': 'Â£33.34', 'link': 'http://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html'}
# {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'rating': 'Three', 'price': 'Â£17.93', 'link': 'http://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html'}
# {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'rating': 'Four', 'price': 'Â£22.60', 'link': 'http://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html'}
# {'title': 'The Black Maria', 'rating': 'One', 'price': 'Â£52.15', 'link': 'http://books.toscrape.com/catalogue/the-black-maria_991/index.html'}
# {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)', 'rating': 'Two', 'price': 'Â£13.99', 'link': 'http://books.toscrape.com/catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html'}
# {'title': "Shakespeare's Sonnets", 'rating': 'Four', 'price': 'Â£20.66', 'link': 'http://books.toscrape.com/catalogue/shakespeares-sonnets_989/index.html'}
# {'title': 'Set Me Free', 'rating': 'Five', 'price': 'Â£17.46', 'link': 'http://books.toscrape.com/catalogue/set-me-free_988/index.html'}
# {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'rating': 'Five', 'price': 'Â£52.29', 'link': 'http://books.toscrape.com/catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html'}
# {'title': 'Rip it Up and Start Again', 'rating': 'Five', 'price': 'Â£35.02', 'link': 'http://books.toscrape.com/catalogue/rip-it-up-and-start-again_986/index.html'}
# {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'rating': 'Three', 'price': 'Â£57.25', 'link': 'http://books.toscrape.com/catalogue/our-band-could-be-your-life-scenes-from-the-american-indie-underground-1981-1991_985/index.html'}
# {'title': 'Olio', 'rating': 'One', 'price': 'Â£23.88', 'link': 'http://books.toscrape.com/catalogue/olio_984/index.html'}
# {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'rating': 'One', 'price': 'Â£37.59', 'link': 'http://books.toscrape.com/catalogue/mesaerion-the-best-science-fiction-stories-1800-1849_983/index.html'}
# {'title': 'Libertarianism for Beginners', 'rating': 'Two', 'price': 'Â£51.33', 'link': 'http://books.toscrape.com/catalogue/libertarianism-for-beginners_982/index.html'}
# {'title': "It's Only the Himalayas", 'rating': 'Two', 'price': 'Â£45.17', 'link': 'http://books.toscrape.com/catalogue/its-only-the-himalayas_981/index.html'}

# %%
df = pd.DataFrame(books, columns = ['title', 'rating', 'price', 'link'])

# %%
df.to_csv('books_to_scrape.csv', index = False)

# %%
df1 = pd.read_csv("books_to_scrape.csv")

# %%
df.head()
# Out:
#                                    title rating    price  \
# 0                   A Light in the Attic  Three  Â£51.77
# 1                     Tipping the Velvet    One  Â£53.74
# 2                             Soumission    One  Â£50.10
# 3                          Sharp Objects   Four  Â£47.82
# 4  Sapiens: A Brief History of Humankind   Five  Â£54.23
#
#                                                 link
# 0  http://books.toscrape.com/catalogue/a-light-in...
# 1  http://books.toscrape.com/catalogue/tipping-th...
# 2  http://books.toscrape.com/catalogue/soumission...
# 3  http://books.toscrape.com/catalogue/sharp-obje...
# 4  http://books.toscrape.com/catalogue/sapiens-a-...

# %% [markdown]
# #### Function to simulate above operation for each page

# %%
import requests
from bs4 import BeautifulSoup
import time

def scrape_books(url):
    # Send a GET request to the website to fetch the HTML content of the page
    response = requests.get(url)
    
    # Use BeautifulSoup to parse the HTML content for data extraction
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Initialize an empty list to store data about each book
    books = []
    
    # Loop through all the 'article' tags with class 'product_pod' (each represents a book)
    for book in soup.find_all('article', class_='product_pod'):
        # Extract the title of the book
        title = book.h3.a['title'] 
        # Extract the rating (second class attribute) 
        rating = book.p['class'][1]  
        # Extract the price
        price = book.find('p', class_='price_color').text  
        # Extract the relative link to the book's detail page
        link = soup.select_one('.product_pod h3 a')['href'] 

        # Add the extracted data to the books list as a dictionary
        books.append({
            'title': title,
            'rating': rating,
            'price': price,
            'link': url[0:37] + link  # Combine base URL with relative link for the complete URL
        })
    
    return books  

# Example usage
# List to store data from all pages
all_books = []
# Base URL for the book pages  
base_url = 'https://books.toscrape.com/catalogue/page-{}.html'  

# Loop over the pages in the range 1 to 51 (50 pages total)
for page in range(1,51):
    # Format URL for the current page
    url = base_url.format(page)  
    # Scrape data from the current page
    iterative_data = scrape_books(url)
    # Add the data from the current page to the main list  
    all_books.extend(iterative_data)  
    # Sleep for 1 second between page requests to be polite to the server
    time.sleep(1)

# %%
all_books
# Out:
# [{'title': 'A Light in the Attic',
#   'rating': 'Three',
#   'price': '£51.77',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Tipping the Velvet',
#   'rating': 'One',
#   'price': '£53.74',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Soumission',
#   'rating': 'One',
#   'price': '£50.10',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Sharp Objects',
#   'rating': 'Four',
#   'price': '£47.82',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Sapiens: A Brief History of Humankind',
#   'rating': 'Five',
#   'price': '£54.23',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'The Requiem Red',
#   'rating': 'One',
#   'price': '£22.65',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'The Dirty Little Secrets of Getting Your Dream Job',
#   'rating': 'Four',
#   'price': '£33.34',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'rating': 'Three',
#   'price': '£17.93',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'rating': 'Four',
#   'price': '£22.60',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'The Black Maria',
#   'rating': 'One',
#   'price': '£52.15',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Starving Hearts (Triangular Trade Trilogy, #1)',
#   'rating': 'Two',
#   'price': '£13.99',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': "Shakespeare's Sonnets",
#   'rating': 'Four',
#   'price': '£20.66',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Set Me Free',
#   'rating': 'Five',
#   'price': '£17.46',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   'rating': 'Five',
#   'price': '£52.29',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Rip it Up and Start Again',
#   'rating': 'Five',
#   'price': '£35.02',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   'rating': 'Three',
#   'price': '£57.25',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Olio',
#   'rating': 'One',
#   'price': '£23.88',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Mesaerion: The Best Science Fiction Stories 1800-1849',
#   'rating': 'One',
#   'price': '£37.59',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'Libertarianism for Beginners',
#   'rating': 'Two',
#   'price': '£51.33',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': "It's Only the Himalayas",
#   'rating': 'Two',
#   'price': '£45.17',
#   'link': 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'},
#  {'title': 'In Her Wake',
#   'rating': 'One',
#   'price': '£12.84',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'How Music Works',
#   'rating': 'Two',
#   'price': '£37.32',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#   'rating': 'Three',
#   'price': '£30.52',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Chase Me (Paris Nights #2)',
#   'rating': 'Five',
#   'price': '£25.27',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Black Dust',
#   'rating': 'Five',
#   'price': '£34.53',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Birdsong: A Story in Pictures',
#   'rating': 'Three',
#   'price': '£54.64',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   'rating': 'Three',
#   'price': '£22.50',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Aladdin and His Wonderful Lamp',
#   'rating': 'Three',
#   'price': '£53.13',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Worlds Elsewhere: Journeys Around Shakespeare’s Globe',
#   'rating': 'Five',
#   'price': '£40.30',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Wall and Piece',
#   'rating': 'Four',
#   'price': '£44.18',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'The Four Agreements: A Practical Guide to Personal Freedom',
#   'rating': 'Five',
#   'price': '£17.66',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#   'rating': 'Three',
#   'price': '£31.05',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'The Elephant Tree',
#   'rating': 'Five',
#   'price': '£23.82',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'The Bear and the Piano',
#   'rating': 'One',
#   'price': '£36.89',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': "Sophie's World",
#   'rating': 'Five',
#   'price': '£15.94',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Penny Maybe',
#   'rating': 'Three',
#   'price': '£33.29',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Maude (1883-1993):She Grew Up with the country',
#   'rating': 'Two',
#   'price': '£18.02',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'In a Dark, Dark Wood',
#   'rating': 'One',
#   'price': '£19.63',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Behind Closed Doors',
#   'rating': 'Four',
#   'price': '£52.22',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': "You can't bury them all: Poems",
#   'rating': 'Two',
#   'price': '£33.63',
#   'link': 'https://books.toscrape.com/catalogue/in-her-wake_980/index.html'},
#  {'title': 'Slow States of Collapse: Poems',
#   'rating': 'Three',
#   'price': '£57.31',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Reasons to Stay Alive',
#   'rating': 'Two',
#   'price': '£26.41',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Private Paris (Private #10)',
#   'rating': 'Five',
#   'price': '£47.61',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   'rating': 'Five',
#   'price': '£23.11',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Without Borders (Wanderlove #1)',
#   'rating': 'Two',
#   'price': '£45.07',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'When We Collided',
#   'rating': 'One',
#   'price': '£31.77',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'We Love You, Charlie Freeman',
#   'rating': 'Five',
#   'price': '£50.27',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Untitled Collection: Sabbath Poems 2014',
#   'rating': 'Four',
#   'price': '£14.27',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   'rating': 'Four',
#   'price': '£44.18',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Unicorn Tracks',
#   'rating': 'Three',
#   'price': '£18.78',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   'rating': 'One',
#   'price': '£25.52',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   'rating': 'One',
#   'price': '£16.28',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#   'rating': 'Three',
#   'price': '£31.12',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'This One Summer',
#   'rating': 'Four',
#   'price': '£19.49',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'Thirst',
#   'rating': 'Five',
#   'price': '£17.27',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'The Torch Is Passed: A Harding Family Story',
#   'rating': 'One',
#   'price': '£19.09',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'The Secret of Dreadwillow Carse',
#   'rating': 'One',
#   'price': '£56.13',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#   'rating': 'One',
#   'price': '£56.41',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'The Past Never Ends',
#   'rating': 'Four',
#   'price': '£56.50',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'The Natural History of Us (The Fine Art of Pretending #2)',
#   'rating': 'Three',
#   'price': '£45.22',
#   'link': 'https://books.toscrape.com/catalogue/slow-states-of-collapse-poems_960/index.html'},
#  {'title': 'The Nameless City (The Nameless City #1)',
#   'rating': 'Four',
#   'price': '£38.16',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Murder That Never Was (Forensic Instincts #5)',
#   'rating': 'Three',
#   'price': '£54.11',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#   'rating': 'Four',
#   'price': '£42.96',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   'rating': 'Four',
#   'price': '£23.89',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   'rating': 'Three',
#   'price': '£16.77',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   'rating': 'Five',
#   'price': '£20.59',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   'rating': 'One',
#   'price': '£37.13',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Electric Pencil: Drawings from Inside State Hospital No. 3',
#   'rating': 'One',
#   'price': '£56.06',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Death of Humanity: and the Case for Life',
#   'rating': 'Four',
#   'price': '£58.11',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#   'rating': 'Three',
#   'price': '£49.05',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Art Forger',
#   'rating': 'Three',
#   'price': '£40.76',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   'rating': 'One',
#   'price': '£19.73',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   'rating': 'Five',
#   'price': '£32.24',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   'rating': 'Four',
#   'price': '£41.83',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Soul Reader',
#   'rating': 'Two',
#   'price': '£39.58',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Security',
#   'rating': 'Two',
#   'price': '£39.25',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Saga, Volume 6 (Saga (Collected Editions) #6)',
#   'rating': 'Three',
#   'price': '£25.02',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Saga, Volume 5 (Saga (Collected Editions) #5)',
#   'rating': 'Two',
#   'price': '£51.04',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Reskilling America: Learning to Labor in the Twenty-First Century',
#   'rating': 'Two',
#   'price': '£19.83',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#   'rating': 'Three',
#   'price': '£50.40',
#   'link': 'https://books.toscrape.com/catalogue/the-nameless-city-the-nameless-city-1_940/index.html'},
#  {'title': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   'rating': 'Five',
#   'price': '£13.61',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Princess Between Worlds (Wide-Awake Princess #5)',
#   'rating': 'Five',
#   'price': '£13.34',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Pop Gun War, Volume 1: Gift',
#   'rating': 'One',
#   'price': '£18.97',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   'rating': 'Two',
#   'price': '£36.28',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Patience',
#   'rating': 'Three',
#   'price': '£10.16',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   'rating': 'Four',
#   'price': '£15.44',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   'rating': 'One',
#   'price': '£48.41',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Online Marketing for Busy Authors: A Step-By-Step Guide',
#   'rating': 'One',
#   'price': '£46.35',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'On a Midnight Clear',
#   'rating': 'Three',
#   'price': '£14.07',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Obsidian (Lux #1)',
#   'rating': 'Two',
#   'price': '£14.86',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'My Paris Kitchen: Recipes and Stories',
#   'rating': 'Two',
#   'price': '£33.37',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Masks and Shadows',
#   'rating': 'Two',
#   'price': '£56.40',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   'rating': 'Four',
#   'price': '£14.02',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   'rating': 'Two',
#   'price': '£46.91',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   'rating': 'Three',
#   'price': '£45.61',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   'rating': 'Two',
#   'price': '£19.92',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Layered: Baking, Building, and Styling Spectacular Cakes',
#   'rating': 'One',
#   'price': '£40.11',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
#   'rating': 'Two',
#   'price': '£53.90',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Join',
#   'rating': 'Five',
#   'price': '£35.67',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'In the Country We Love: My Family Divided',
#   'rating': 'Four',
#   'price': '£22.00',
#   'link': 'https://books.toscrape.com/catalogue/princess-jellyfish-2-in-1-omnibus-vol-01-princess-jellyfish-2-in-1-omnibus-1_920/index.html'},
#  {'title': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#   'rating': 'Five',
#   'price': '£57.36',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   'rating': 'Two',
#   'price': '£29.17',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'I am a Hero Omnibus Volume 1',
#   'rating': 'Three',
#   'price': '£54.63',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'How to Be Miserable: 40 Strategies You Already Use',
#   'rating': 'One',
#   'price': '£46.03',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Her Backup Boyfriend (The Sorensen Family #1)',
#   'rating': 'One',
#   'price': '£33.97',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Giant Days, Vol. 2 (Giant Days #5-8)',
#   'rating': 'Two',
#   'price': '£22.11',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   'rating': 'Three',
#   'price': '£29.69',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'First and First (Five Boroughs #3)',
#   'rating': 'Four',
#   'price': '£15.97',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Fifty Shades Darker (Fifty Shades #2)',
#   'rating': 'One',
#   'price': '£21.96',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#   'rating': 'Two',
#   'price': '£54.35',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#   'rating': 'Two',
#   'price': '£37.97',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Danganronpa Volume 1',
#   'rating': 'Four',
#   'price': '£51.99',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Crown of Midnight (Throne of Glass #2)',
#   'rating': 'Three',
#   'price': '£43.29',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Codename Baboushka, Volume 1: The Conclave of Death',
#   'rating': 'Four',
#   'price': '£36.72',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Camp Midnight',
#   'rating': 'Four',
#   'price': '£17.08',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   'rating': 'Five',
#   'price': '£29.14',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Burning',
#   'rating': 'Three',
#   'price': '£28.81',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Bossypants',
#   'rating': 'Two',
#   'price': '£49.46',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   'rating': 'Two',
#   'price': '£37.92',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#   'rating': 'Two',
#   'price': '£28.09',
#   'link': 'https://books.toscrape.com/catalogue/immunity-how-elie-metchnikoff-changed-the-course-of-modern-medicine_900/index.html'},
#  {'title': 'Algorithms to Live By: The Computer Science of Human Decisions',
#   'rating': 'One',
#   'price': '£30.81',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'A World of Flavor: Your Gluten Free Passport',
#   'rating': 'One',
#   'price': '£42.95',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#   'rating': 'Five',
#   'price': '£56.76',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'A Murder in Time',
#   'rating': 'One',
#   'price': '£16.64',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'A Flight of Arrows (The Pathfinders #2)',
#   'rating': 'Five',
#   'price': '£55.53',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'A Fierce and Subtle Poison',
#   'rating': 'Four',
#   'price': '£28.13',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#   'rating': 'One',
#   'price': '£52.37',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': '(Un)Qualified: How God Uses Broken People to Do Big Things',
#   'rating': 'Five',
#   'price': '£54.00',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'You Are What You Love: The Spiritual Power of Habit',
#   'rating': 'Four',
#   'price': '£21.87',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#   'rating': 'Four',
#   'price': '£43.30',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'Tuesday Nights in 1980',
#   'rating': 'Two',
#   'price': '£21.04',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'Tracing Numbers on a Train',
#   'rating': 'Three',
#   'price': '£41.60',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'Throne of Glass (Throne of Glass #1)',
#   'rating': 'Three',
#   'price': '£35.07',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#   'rating': 'One',
#   'price': '£59.64',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'Thirteen Reasons Why',
#   'rating': 'One',
#   'price': '£52.72',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'The White Cat and the Monk: A Retelling of the Poem “Pangur Bán”',
#   'rating': 'Four',
#   'price': '£58.08',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'The Wedding Dress',
#   'rating': 'One',
#   'price': '£24.12',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'The Vacationers',
#   'rating': 'Four',
#   'price': '£42.15',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'The Third Wave: An Entrepreneur’s Vision of the Future',
#   'rating': 'Five',
#   'price': '£12.61',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'The Stranger',
#   'rating': 'Four',
#   'price': '£17.44',
#   'link': 'https://books.toscrape.com/catalogue/algorithms-to-live-by-the-computer-science-of-human-decisions_880/index.html'},
#  {'title': 'The Shadow Hero (The Shadow Hero)',
#   'rating': 'One',
#   'price': '£33.14',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Secret (The Secret #1)',
#   'rating': 'Four',
#   'price': '£27.37',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Regional Office Is Under Attack!',
#   'rating': 'Five',
#   'price': '£51.36',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Psychopath Test: A Journey Through the Madness Industry',
#   'rating': 'Two',
#   'price': '£36.00',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Project',
#   'rating': 'One',
#   'price': '£10.65',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Power of Now: A Guide to Spiritual Enlightenment',
#   'rating': 'Two',
#   'price': '£43.54',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': "The Omnivore's Dilemma: A Natural History of Four Meals",
#   'rating': 'Two',
#   'price': '£38.21',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   'rating': 'Five',
#   'price': '£37.34',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   'rating': 'Four',
#   'price': '£44.10',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Mistake (Off-Campus #2)',
#   'rating': 'Three',
#   'price': '£43.29',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': "The Matchmaker's Playbook (Wingmen Inc. #1)",
#   'rating': 'One',
#   'price': '£55.85',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   'rating': 'Two',
#   'price': '£37.60',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   'rating': 'One',
#   'price': '£10.97',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Kite Runner',
#   'rating': 'Four',
#   'price': '£41.82',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The House by the Lake',
#   'rating': 'One',
#   'price': '£36.95',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Glittering Court (The Glittering Court #1)',
#   'rating': 'One',
#   'price': '£44.28',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Girl on the Train',
#   'rating': 'Two',
#   'price': '£55.02',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Genius of Birds',
#   'rating': 'One',
#   'price': '£17.24',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Emerald Mystery',
#   'rating': 'Two',
#   'price': '£23.15',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   'rating': 'One',
#   'price': '£41.25',
#   'link': 'https://books.toscrape.com/catalogue/the-shadow-hero-the-shadow-hero_860/index.html'},
#  {'title': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#   'rating': 'Three',
#   'price': '£32.00',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': "The Artist's Way: A Spiritual Path to Higher Creativity",
#   'rating': 'Five',
#   'price': '£38.49',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'The Art of War',
#   'rating': 'Five',
#   'price': '£33.34',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'The Argonauts',
#   'rating': 'Two',
#   'price': '£10.93',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   'rating': 'Three',
#   'price': '£27.55',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Suddenly in Love (Lake Haven #1)',
#   'rating': 'Two',
#   'price': '£55.99',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Something More Than This',
#   'rating': 'Four',
#   'price': '£16.24',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Soft Apocalypse',
#   'rating': 'Two',
#   'price': '£26.12',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': "So You've Been Publicly Shamed",
#   'rating': 'Two',
#   'price': '£12.23',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Shoe Dog: A Memoir by the Creator of NIKE',
#   'rating': 'Two',
#   'price': '£23.99',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Shobu Samurai, Project Aryoku (#3)',
#   'rating': 'Three',
#   'price': '£29.06',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Secrets and Lace (Fatal Hearts #1)',
#   'rating': 'One',
#   'price': '£20.27',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Scarlett Epstein Hates It Here',
#   'rating': 'Five',
#   'price': '£43.55',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Romero and Juliet: A Tragic Tale of Love and Zombies',
#   'rating': 'One',
#   'price': '£36.94',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Redeeming Love',
#   'rating': 'Five',
#   'price': '£20.47',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#   'rating': 'One',
#   'price': '£41.06',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Poems That Make Grown Women Cry',
#   'rating': 'Four',
#   'price': '£14.19',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Nightingale, Sing',
#   'rating': 'One',
#   'price': '£38.28',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Night Sky with Exit Wounds',
#   'rating': 'One',
#   'price': '£41.05',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Mrs. Houdini',
#   'rating': 'Five',
#   'price': '£30.25',
#   'link': 'https://books.toscrape.com/catalogue/the-bridge-to-consciousness-im-writing-the-bridge-between-science-and-our-old-and-new-beliefs_840/index.html'},
#  {'title': 'Modern Romance',
#   'rating': 'Five',
#   'price': '£28.26',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Miss Peregrine’s Home for Peculiar Children (Miss Peregrine’s Peculiar Children #1)',
#   'rating': 'One',
#   'price': '£10.76',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Louisa: The Extraordinary Life of Mrs. Adams',
#   'rating': 'Two',
#   'price': '£16.85',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Little Red',
#   'rating': 'Three',
#   'price': '£13.47',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Library of Souls (Miss Peregrine’s Peculiar Children #3)',
#   'rating': 'Five',
#   'price': '£48.56',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Large Print Heart of the Pride',
#   'rating': 'Two',
#   'price': '£19.15',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   'rating': 'Four',
#   'price': '£57.36',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Hollow City (Miss Peregrine’s Peculiar Children #2)',
#   'rating': 'One',
#   'price': '£42.98',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Grumbles',
#   'rating': 'Two',
#   'price': '£22.16',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Full Moon over Noah’s Ark: An Odyssey to Mount Ararat and Beyond',
#   'rating': 'Four',
#   'price': '£49.43',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Frostbite (Vampire Academy #2)',
#   'rating': 'Five',
#   'price': '£29.99',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Follow You Home',
#   'rating': 'One',
#   'price': '£21.36',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'First Steps for New Christians (Print Edition)',
#   'rating': 'One',
#   'price': '£29.00',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Finders Keepers (Bill Hodges Trilogy #2)',
#   'rating': 'Five',
#   'price': '£53.53',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Fables, Vol. 1: Legends in Exile (Fables #1)',
#   'rating': 'Four',
#   'price': '£41.62',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Eureka Trivia 6.0',
#   'rating': 'Four',
#   'price': '£54.59',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Drive: The Surprising Truth About What Motivates Us',
#   'rating': 'Four',
#   'price': '£34.95',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Done Rubbed Out (Reightman & Bailey #1)',
#   'rating': 'Five',
#   'price': '£37.72',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Doing It Over (Most Likely To #1)',
#   'rating': 'Three',
#   'price': '£35.61',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#   'rating': 'Three',
#   'price': '£42.16',
#   'link': 'https://books.toscrape.com/catalogue/modern-romance_820/index.html'},
#  {'title': 'Dark Notes',
#   'rating': 'Five',
#   'price': '£19.19',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   'rating': 'Three',
#   'price': '£19.43',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Close to You',
#   'rating': 'Four',
#   'price': '£49.46',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Chasing Heaven: What Dying Taught Me About Living',
#   'rating': 'Two',
#   'price': '£37.80',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Big Magic: Creative Living Beyond Fear',
#   'rating': 'Three',
#   'price': '£30.80',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   'rating': 'Two',
#   'price': '£27.43',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Beauty Restored (Riley Family Legacy Novellas #3)',
#   'rating': 'Two',
#   'price': '£11.11',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Batman: The Long Halloween (Batman)',
#   'rating': 'Two',
#   'price': '£36.50',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Batman: The Dark Knight Returns (Batman)',
#   'rating': 'Five',
#   'price': '£15.38',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': "Ayumi's Violin",
#   'rating': 'Two',
#   'price': '£15.48',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Anonymous',
#   'rating': 'Four',
#   'price': '£46.82',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Amy Meets the Saints and Sages',
#   'rating': 'Three',
#   'price': '£18.46',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Amid the Chaos',
#   'rating': 'One',
#   'price': '£36.58',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Amatus',
#   'rating': 'Five',
#   'price': '£50.54',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Agnostic: A Spirited Manifesto',
#   'rating': 'Five',
#   'price': '£12.51',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Zealot: The Life and Times of Jesus of Nazareth',
#   'rating': 'Three',
#   'price': '£24.70',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'You (You #1)',
#   'rating': 'Five',
#   'price': '£43.61',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   'rating': 'Four',
#   'price': '£37.34',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Wild Swans',
#   'rating': 'Two',
#   'price': '£14.36',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   'rating': 'Four',
#   'price': '£52.65',
#   'link': 'https://books.toscrape.com/catalogue/dark-notes_800/index.html'},
#  {'title': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   'rating': 'Four',
#   'price': '£38.20',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': "What's It Like in Space?: Stories from Astronauts Who've Been There",
#   'rating': 'Two',
#   'price': '£19.60',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#   'rating': 'One',
#   'price': '£53.90',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': "Walt Disney's Alice in Wonderland",
#   'rating': 'Five',
#   'price': '£12.96',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': 'V for Vendetta (V for Vendetta Complete)',
#   'rating': 'Four',
#   'price': '£37.10',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': 'Until Friday Night (The Field Party #1)',
#   'rating': 'Two',
#   'price': '£46.31',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#   'rating': 'Two',
#   'price': '£45.95',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': 'Twenty Yawns',
#   'rating': 'Two',
#   'price': '£22.08',
#   'link': 'https://books.toscrape.com/catalogue/whole-lotta-creativity-going-on-60-fun-and-unusual-exercises-to-awaken-and-strengthen-your-creativity_780/index.html'},
#  {'title': 'Through the Woods',
#   'rating': 'Two',
#   'price': '£25.38',
# ...
#  {'title': 'Code Name Verity (Code Name Verity #1)',
#   'rating': 'Four',
#   'price': '£22.13',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Clockwork Angel (The Infernal Devices #1)',
#   'rating': 'One',
#   'price': '£44.14',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'City of Glass (The Mortal Instruments #3)',
#   'rating': 'Four',
#   'price': '£56.02',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'City of Fallen Angels (The Mortal Instruments #4)',
#   'rating': 'Four',
#   'price': '£11.23',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'City of Bones (The Mortal Instruments #1)',
#   'rating': 'One',
#   'price': '£43.28',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'City of Ashes (The Mortal Instruments #2)',
#   'rating': 'One',
#   'price': '£47.27',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Cell',
#   'rating': 'Four',
#   'price': '£20.29',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Catching Jordan (Hundred Oaks)',
#   'rating': 'Three',
#   'price': '£50.83',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Carry On, Warrior: Thoughts on Life Unarmed',
#   'rating': 'Three',
#   'price': '£31.85',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Carrie',
#   'rating': 'Two',
#   'price': '£46.23',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   'rating': 'Four',
#   'price': '£37.80',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Brain on Fire: My Month of Madness',
#   'rating': 'Five',
#   'price': '£49.32',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Batman: Europa',
#   'rating': 'Two',
#   'price': '£32.01',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Barefoot Contessa Back to Basics',
#   'rating': 'One',
#   'price': '£28.01',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   'rating': 'Five',
#   'price': '£50.62',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Balloon Animals',
#   'rating': 'Three',
#   'price': '£17.03',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Art Ops Vol. 1',
#   'rating': 'Three',
#   'price': '£48.80',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   'rating': 'Four',
#   'price': '£58.14',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Angels Walking (Angels Walking #1)',
#   'rating': 'Two',
#   'price': '£34.20',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'Angels & Demons (Robert Langdon #1)',
#   'rating': 'Three',
#   'price': '£51.48',
#   'link': 'https://books.toscrape.com/catalogue/code-name-verity-code-name-verity-1_680/index.html'},
#  {'title': 'All the Light We Cannot See',
#   'rating': 'Five',
#   'price': '£29.87',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   'rating': 'Two',
#   'price': '£10.90',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'Abstract City',
#   'rating': 'Five',
#   'price': '£56.37',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'A Time of Torment (Charlie Parker #14)',
#   'rating': 'Five',
#   'price': '£48.35',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'A Study in Scarlet (Sherlock Holmes #1)',
#   'rating': 'Two',
#   'price': '£16.73',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#   'rating': 'Two',
#   'price': '£56.48',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': "A People's History of the United States",
#   'rating': 'Two',
#   'price': '£40.79',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'A Man Called Ove',
#   'rating': 'One',
#   'price': '£39.72',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'A Distant Mirror: The Calamitous 14th Century',
#   'rating': 'Three',
#   'price': '£14.58',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'A Brush of Wings (Angels Walking #3)',
#   'rating': 'One',
#   'price': '£55.51',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': '1491: New Revelations of the Americas Before Columbus',
#   'rating': 'Three',
#   'price': '£21.80',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'The Three Searches, Meaning, and the Story',
#   'rating': 'Three',
#   'price': '£13.33',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'Searching for Meaning in Gailana',
#   'rating': 'One',
#   'price': '£38.73',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'Rook',
#   'rating': 'Four',
#   'price': '£37.86',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'My Kitchen Year: 136 Recipes That Saved My Life',
#   'rating': 'Two',
#   'price': '£11.53',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': '13 Hours: The Inside Account of What Really Happened In Benghazi',
#   'rating': 'One',
#   'price': '£27.06',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': "Will You Won't You Want Me?",
#   'rating': 'Three',
#   'price': '£13.86',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'Tipping Point for Planet Earth: How Close Are We to the Edge?',
#   'rating': 'One',
#   'price': '£37.55',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'The Star-Touched Queen',
#   'rating': 'Five',
#   'price': '£32.30',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'The Silent Sister (Riley MacPherson #1)',
#   'rating': 'Five',
#   'price': '£46.29',
#   'link': 'https://books.toscrape.com/catalogue/all-the-light-we-cannot-see_660/index.html'},
#  {'title': 'The Midnight Watch: A Novel of the Titanic and the Californian',
#   'rating': 'One',
#   'price': '£26.20',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'The Lonely City: Adventures in the Art of Being Alone',
#   'rating': 'Two',
#   'price': '£33.26',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   'rating': 'Four',
#   'price': '£59.15',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'The Golden Condom: And Other Essays on Love Lost and Found',
#   'rating': 'One',
#   'price': '£39.43',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'The Epidemic (The Program 0.6)',
#   'rating': 'Five',
#   'price': '£14.44',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'The Dinner Party',
#   'rating': 'Two',
#   'price': '£56.54',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'The Diary of a Young Girl',
#   'rating': 'Three',
#   'price': '£59.90',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'The Children',
#   'rating': 'Three',
#   'price': '£11.88',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Stars Above (The Lunar Chronicles #4.5)',
#   'rating': 'Two',
#   'price': '£48.05',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   'rating': 'Three',
#   'price': '£21.21',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Raspberry Pi Electronics Projects for the Evil Genius',
#   'rating': 'Four',
#   'price': '£49.67',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   'rating': 'One',
#   'price': '£43.14',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Psycho: Sanitarium (Psycho #1.5)',
#   'rating': 'Five',
#   'price': '£36.97',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Poisonous (Max Revere Novels #3)',
#   'rating': 'Three',
#   'price': '£26.80',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'One with You (Crossfire #5)',
#   'rating': 'Four',
#   'price': '£15.71',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'No Love Allowed (Dodge Cove #1)',
#   'rating': 'Four',
#   'price': '£54.65',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Murder at the 42nd Street Library (Raymond Ambler #1)',
#   'rating': 'Four',
#   'price': '£54.36',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Most Wanted',
#   'rating': 'Three',
#   'price': '£35.28',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Love, Lies and Spies',
#   'rating': 'Two',
#   'price': '£20.55',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'How to Speak Golf: An Illustrated Guide to Links Lingo',
#   'rating': 'Five',
#   'price': '£58.32',
#   'link': 'https://books.toscrape.com/catalogue/the-midnight-watch-a-novel-of-the-titanic-and-the-californian_640/index.html'},
#  {'title': 'Hide Away (Eve Duncan #20)',
#   'rating': 'One',
#   'price': '£11.84',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Furiously Happy: A Funny Book About Horrible Things',
#   'rating': 'Four',
#   'price': '£41.46',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Everyday Italian: 125 Simple and Delicious Recipes',
#   'rating': 'Five',
#   'price': '£20.10',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': "Equal Is Unfair: America's Misguided Fight Against Income Inequality",
#   'rating': 'One',
#   'price': '£56.86',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Eleanor & Park',
#   'rating': 'Five',
#   'price': '£56.51',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Dirty (Dive Bar #1)',
#   'rating': 'Four',
#   'price': '£40.83',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Can You Keep a Secret? (Fear Street Relaunch #4)',
#   'rating': 'One',
#   'price': '£48.64',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Boar Island (Anna Pigeon #19)',
#   'rating': 'Three',
#   'price': '£59.48',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'A Paris Apartment',
#   'rating': 'Four',
#   'price': '£39.01',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   'rating': 'One',
#   'price': '£38.77',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Troublemaker: Surviving Hollywood and Scientology',
#   'rating': 'Two',
#   'price': '£48.39',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'The Widow',
#   'rating': 'Two',
#   'price': '£27.26',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   'rating': 'Four',
#   'price': '£11.68',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'The Improbability of Love',
#   'rating': 'One',
#   'price': '£59.45',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'The Art of Startup Fundraising',
#   'rating': 'Three',
#   'price': '£21.00',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Take Me Home Tonight (Rock Star Romance #3)',
#   'rating': 'Three',
#   'price': '£53.98',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Sleeping Giants (Themis Files #1)',
#   'rating': 'One',
#   'price': '£48.74',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   'rating': 'Two',
#   'price': '£21.15',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Playing with Fire',
#   'rating': 'Three',
#   'price': '£13.71',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'},
#  {'title': 'Off the Hook (Fishing for Trouble #1)',
#   'rating': 'Three',
#   'price': '£47.67',
#   'link': 'https://books.toscrape.com/catalogue/hide-away-eve-duncan-20_620/index.html'}]

# %%
df = pd.DataFrame(all_books, columns = ['title', 'rating', 'price', 'link'])

# %%
df.to_csv('books_to_scrape.csv', index = False)

# %%
df1 = pd.read_csv("books_to_scrape.csv")

# %%
df1.head()
# Out:
#                                    title rating   price  \
# 0                   A Light in the Attic  Three  £51.77
# 1                     Tipping the Velvet    One  £53.74
# 2                             Soumission    One  £50.10
# 3                          Sharp Objects   Four  £47.82
# 4  Sapiens: A Brief History of Humankind   Five  £54.23
#
#                                                 link
# 0  https://books.toscrape.com/catalogue/a-light-i...
# 1  https://books.toscrape.com/catalogue/a-light-i...
# 2  https://books.toscrape.com/catalogue/a-light-i...
# 3  https://books.toscrape.com/catalogue/a-light-i...
# 4  https://books.toscrape.com/catalogue/a-light-i...

# %%
df1.shape
# Out:
# (400, 4)
